# %%
# !pip install neuralforecast
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting neuralforecast
#   Downloading neuralforecast-1.5.0-py3-none-any.whl (141 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.8/141.8 kB 1.3 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=1.3.5 in /usr/local/lib/python3.10/dist-packages (from neuralforecast) (1.5.3)
# Collecting ray[tune]>=2.2.0
#   Downloading ray-2.4.0-cp310-cp310-manylinux2014_x86_64.whl (58.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.6/58.6 MB 10.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.21.6 in /usr/local/lib/python3.10/dist-packages (from neuralforecast) (1.22.4)
# Collecting pytorch-lightning>=2.0.0
#   Downloading pytorch_lightning-2.0.2-py3-none-any.whl (719 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 719.0/719.0 kB 17.9 MB/s eta 0:00:00
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from neuralforecast) (2.0.0+cu118)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.5->neuralforecast) (2022.7.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.5->neuralforecast) (2.8.2)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning>=2.0.0->neuralforecast) (4.5.0)
# Requirement already satisfied: fsspec[http]>2021.06.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning>=2.0.0->neuralforecast) (2023.4.0)
# Requirement already satisfied: tqdm>=4.57.0 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning>=2.0.0->neuralforecast) (4.65.0)
# Requirement already satisfied: PyYAML>=5.4 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning>=2.0.0->neuralforecast) (6.0)
# Collecting lightning-utilities>=0.7.0
#   Downloading lightning_utilities-0.8.0-py3-none-any.whl (20 kB)
# Collecting torchmetrics>=0.7.0
#   Downloading torchmetrics-0.11.4-py3-none-any.whl (519 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.2/519.2 kB 14.6 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=17.1 in /usr/local/lib/python3.10/dist-packages (from pytorch-lightning>=2.0.0->neuralforecast) (23.1)
# Collecting aiosignal
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from ray[tune]>=2.2.0->neuralforecast) (3.12.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from ray[tune]>=2.2.0->neuralforecast) (2.27.1)
# Collecting virtualenv<20.21.1,>=20.0.24
#   Downloading virtualenv-20.21.0-py3-none-any.whl (8.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 26.1 MB/s eta 0:00:00
# Collecting frozenlist
#   Downloading frozenlist-1.3.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (149 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.6/149.6 kB 5.1 MB/s eta 0:00:00
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.10/dist-packages (from ray[tune]>=2.2.0->neuralforecast) (8.1.3)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.10/dist-packages (from ray[tune]>=2.2.0->neuralforecast) (4.3.3)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ray[tune]>=2.2.0->neuralforecast) (1.0.5)
# Collecting grpcio<=1.51.3,>=1.42.0
#   Downloading grpcio-1.51.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 14.8 MB/s eta 0:00:00
# Requirement already satisfied: attrs in /usr/local/lib/python3.10/dist-packages (from ray[tune]>=2.2.0->neuralforecast) (23.1.0)
# Requirement already satisfied: protobuf!=3.19.5,>=3.15.3 in /usr/local/lib/python3.10/dist-packages (from ray[tune]>=2.2.0->neuralforecast) (3.20.3)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from ray[tune]>=2.2.0->neuralforecast) (0.8.10)
# Collecting tensorboardX>=1.9
#   Downloading tensorboardX-2.6-py2.py3-none-any.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 7.7 MB/s eta 0:00:00
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.0->neuralforecast) (3.1)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.0->neuralforecast) (2.0.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.0->neuralforecast) (3.1.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.0->neuralforecast) (1.11.1)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=2.0.0->neuralforecast) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=2.0.0->neuralforecast) (16.0.2)
# Collecting aiohttp!=4.0.0a0,!=4.0.0a1
#   Downloading aiohttp-3.8.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 11.3 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas>=1.3.5->neuralforecast) (1.16.0)
# Collecting distlib<1,>=0.3.6
#   Downloading distlib-0.3.6-py2.py3-none-any.whl (468 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 468.5/468.5 kB 21.4 MB/s eta 0:00:00
# Requirement already satisfied: platformdirs<4,>=2.4 in /usr/local/lib/python3.10/dist-packages (from virtualenv<20.21.1,>=20.0.24->ray[tune]>=2.2.0->neuralforecast) (3.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=2.0.0->neuralforecast) (2.1.2)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema->ray[tune]>=2.2.0->neuralforecast) (0.19.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->ray[tune]>=2.2.0->neuralforecast) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->ray[tune]>=2.2.0->neuralforecast) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->ray[tune]>=2.2.0->neuralforecast) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->ray[tune]>=2.2.0->neuralforecast) (3.4)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=2.0.0->neuralforecast) (1.3.0)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.9.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (268 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 7.8 MB/s eta 0:00:00
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 15.5 MB/s eta 0:00:00
# Installing collected packages: distlib, virtualenv, tensorboardX, multidict, lightning-utilities, grpcio, frozenlist, async-timeout, yarl, aiosignal, ray, aiohttp, torchmetrics, pytorch-lightning, neuralforecast
#   Attempting uninstall: grpcio
#     Found existing installation: grpcio 1.54.0
#     Uninstalling grpcio-1.54.0:
#       Successfully uninstalled grpcio-1.54.0
# Successfully installed aiohttp-3.8.4 aiosignal-1.3.1 async-timeout-4.0.2 distlib-0.3.6 frozenlist-1.3.3 grpcio-1.51.3 lightning-utilities-0.8.0 multidict-6.0.4 neuralforecast-1.5.0 pytorch-lightning-2.0.2 ray-2.4.0 tensorboardX-2.6 torchmetrics-0.11.4 virtualenv-20.21.0 yarl-1.9.2

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from neuralforecast import NeuralForecast
from neuralforecast.models import NBEATSx
from neuralforecast.losses.pytorch import MQLoss, DistributionLoss, MSE, MAE
from neuralforecast.tsdataset import TimeSeriesDataset, TimeSeriesLoader
from numpy.random import seed
from random import randrange
from neuralforecast.losses.numpy import rmse, mape
from pandas.tseries.holiday import USFederalHolidayCalendar
from pandas.tseries.offsets import CustomBusinessDay
from neuralforecast.utils import AirPassengers, AirPassengersPanel, AirPassengersStatic

# %%
df = pd.read_excel("Temperature in Sao Paulo.xlsx",index_col='Date',parse_dates=True, sheet_name="S&P 500")

# %%
import seaborn as sb
dataplot = sb.heatmap(df.corr(), cmap="YlGnBu", annot=True)
  
# displaying heatmap
plt.show()

# %%
df = pd.read_excel("Temperature in Sao Paulo (NBEATSx).xlsx",index_col='Date',parse_dates=True, sheet_name="S&P 500")

# %%
df.reset_index(inplace=True)
df.rename(columns={'Date':'ds'}, inplace=True)
df.rename(columns={'Realised':'y'}, inplace=True)
train = df.iloc[:int(len(df['y'])*0.7)]
test = df.iloc[int(len(df['y'])*0.7)]
validation_length=int(len(df['y'])*0.7)-int(len(df['y'])*0.6)

# %% [markdown]
# Epoch: 150 | Inputs: 63 | MLP units: [[250, 250], [250, 250]] | Loss: MSE() | Scaler Type: robust
# Stack Types: ['trend', 'seasonality'] | Learning Rate: 0.0005

# %% [markdown]
# # H=1 Forecasts

# %%
Accuracy=[]
RMSE=[]
Quasilikelihood=[]

# %%
test_length=len(df["y"])-int(len(df['y'])*0.7)

# %%
for i in range(13):
  model = NBEATSx(h=1, input_size=21,
                  loss=MQLoss(level=[90]),
                  scaler_type='minmax',
                  learning_rate= 0.0001,
                  stack_types=['identity','identity'],
                  n_blocks=[1,1],
                  mlp_units= [[512, 512], [512, 512]],
                  windows_batch_size=60,
                  num_lr_decays=5,
                  val_check_steps=100,
                  n_harmonics=0, n_polynomials=0,
                  hist_exog_list=['VIX','Temp. in Sao Paulo'],
                  max_steps=150,
                  early_stop_patience_steps=1,
                  random_seed=randrange(129228148)
                  )
  fcst = NeuralForecast(models=[model],freq=CustomBusinessDay(calendar=USFederalHolidayCalendar()))
  forecasts = fcst.cross_validation(df=df,val_size=10,static_df=AirPassengersStatic,n_windows=None, test_size=test_length,step_size=1)
  forecasts = forecasts.dropna()
  if "NBEATSx-median" not in list(forecasts.columns.values):
    Y_hat=forecasts["NBEATSx"].values
  else:
    Y_hat=forecasts["NBEATSx-median"].values
  Y_true=forecasts["y"].values
  RMSE.append(np.sum(np.sqrt((Y_true-Y_hat)**2))/len(Y_true))
  Accuracy.append((1-np.sum(np.sqrt((Y_true-Y_hat)**2)/Y_true)/(len(Y_true)))*100)
  Quasilikelihood.append(np.sum(Y_true/Y_hat-np.log(Y_true/Y_hat)-1)/len(Y_true))
# Out:
# INFO:lightning_fabric.utilities.seed:Global seed set to 104463731
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# INFO:lightning_fabric.utilities.seed:Global seed set to 22068138
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# INFO:lightning_fabric.utilities.seed:Global seed set to 125681447
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# INFO:lightning_fabric.utilities.seed:Global seed set to 58823735
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# INFO:lightning_fabric.utilities.seed:Global seed set to 98207660
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# INFO:lightning_fabric.utilities.seed:Global seed set to 85282373
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# INFO:lightning_fabric.utilities.seed:Global seed set to 34544794
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# INFO:lightning_fabric.utilities.seed:Global seed set to 63502219
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# INFO:lightning_fabric.utilities.seed:Global seed set to 90857383
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# INFO:lightning_fabric.utilities.seed:Global seed set to 73799539
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# INFO:lightning_fabric.utilities.seed:Global seed set to 87134550
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# INFO:lightning_fabric.utilities.seed:Global seed set to 97085816
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# INFO:lightning_fabric.utilities.seed:Global seed set to 91221762
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]

# %%
Accuracy
# Out:
# [68.58897323429076,
#  67.56088979595327,
#  68.274037231599,
#  69.20594367396895,
#  68.70222278733216,
#  66.68036332411592,
#  67.8320523676944,
#  68.49765912934707,
#  68.13463927443273,
#  69.3513679093793,
#  67.7538402902548,
#  68.94935971330068,
#  68.0062030856847,
#  68.19060831009526,
#  68.10044450274724]

# %%
RMSE
# Out:
# [0.0020276407811187715,
#  0.002078635273943827,
#  0.002030418242027521,
#  0.0020203479274729296,
#  0.0020348030758507983,
#  0.0020692884547231344,
#  0.0020393023705363965,
#  0.002026771097422014,
#  0.0020565082065813183,
#  0.0020212404922091893,
#  0.0020524631712263036,
#  0.0020343252248697045,
#  0.002038835991901058,
#  0.0020363525302155004,
#  0.0020379848321943755]

# %%
Quasilikelihood
# Out:
# [0.07378433249351553,
#  0.07768162995748354,
#  0.07503853413331396,
#  0.07560965761099057,
#  0.0757146826809102,
#  0.07506563319647612,
#  0.07538886229968872,
#  0.07586499501680957,
#  0.07537240544741916,
#  0.0756714121289626,
#  0.07671094965703752,
#  0.07841049645133744,
#  0.07497784627624751,
#  0.07481649344098035,
#  0.07541949539288174]

# %%
plt.plot(forecasts["ds"], Y_true)
plt.plot(forecasts["ds"], Y_hat) 
plt.ylabel("S&P 500 Realized Volatility")
# Out:
# Text(0, 0.5, 'S&P 500 Realized Volatility')

# %% [markdown]
# # H=3 Forecasts

# %%
Accuracy=[]
RMSE=[]
Quasilikelihood=[]
test_length=len(df["y"])-int(len(df['y'])*0.7)

# %%
for i in range(14):
  model = NBEATSx(h=3, input_size=21,
                  loss=MQLoss(level=[90]),
                  scaler_type='minmax',
                  learning_rate= 0.0001,
                  stack_types=['identity','identity'],
                  n_blocks=[1,1],
                  mlp_units= [[512, 512], [512, 512]],
                  windows_batch_size=60,
                  num_lr_decays=5,
                  val_check_steps=100,
                  n_harmonics=0, n_polynomials=0,
                  hist_exog_list=['VIX','Temp. in Sao Paulo'],
                  max_steps=150,
                  early_stop_patience_steps=1,
                  random_seed=randrange(129228148)
                  )
  fcst = NeuralForecast(models=[model],freq=CustomBusinessDay(calendar=USFederalHolidayCalendar()))
  forecasts = fcst.cross_validation(df=df,val_size=9,static_df=AirPassengersStatic,n_windows=None, test_size=test_length-1,step_size=3)
  forecasts = forecasts.dropna()
  if "NBEATSx-median" not in list(forecasts.columns.values):
    Y_hat=forecasts["NBEATSx"].values
  else:
    Y_hat=forecasts["NBEATSx-median"].values
  Y_true=forecasts["y"].values
  RMSE.append(np.sum(np.sqrt((Y_true-Y_hat)**2))/len(Y_true))
  Accuracy.append((1-np.sum(np.sqrt((Y_true-Y_hat)**2)/Y_true)/(len(Y_true)))*100)
  Quasilikelihood.append(np.sum(Y_true/Y_hat-np.log(Y_true/Y_hat)-1)/len(Y_true))
# Out:
# INFO:lightning_fabric.utilities.seed:Global seed set to 72900851
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# INFO:lightning_fabric.utilities.seed:Global seed set to 27792637
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# INFO:lightning_fabric.utilities.seed:Global seed set to 36107935
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# INFO:lightning_fabric.utilities.seed:Global seed set to 784559
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# INFO:lightning_fabric.utilities.seed:Global seed set to 30990054
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# INFO:lightning_fabric.utilities.seed:Global seed set to 122560278
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# INFO:lightning_fabric.utilities.seed:Global seed set to 44266542
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# INFO:lightning_fabric.utilities.seed:Global seed set to 54844478
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# INFO:lightning_fabric.utilities.seed:Global seed set to 62381610
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# INFO:lightning_fabric.utilities.seed:Global seed set to 23574486
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# INFO:lightning_fabric.utilities.seed:Global seed set to 99741491
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# INFO:lightning_fabric.utilities.seed:Global seed set to 63023224
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# INFO:lightning_fabric.utilities.seed:Global seed set to 98500655
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# INFO:lightning_fabric.utilities.seed:Global seed set to 126006365
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]

# %%
RMSE
# Out:
# [0.002237018462559533,
#  0.0022172130024710936,
#  0.002289687041890069,
#  0.0022380801367094614,
#  0.002208694248586458,
#  0.002210832658488672,
#  0.002308654319897905,
#  0.0022143225257686447,
#  0.002225575453140169,
#  0.0022531996700586366,
#  0.0022240853127543374,
#  0.0022511500002789825,
#  0.0022413931139294014,
#  0.002239327881148845,
#  0.002259480926348636]

# %%
Accuracy
# Out:
# [65.84667261119115,
#  66.78501586476318,
#  64.56314057077041,
#  66.0996669641722,
#  66.03044222017148,
#  65.98705783880322,
#  64.03598620282244,
#  66.15318247613136,
#  66.26462115480429,
#  65.01784640927302,
#  66.1779956269825,
#  65.04819168671241,
#  64.78740157358997,
#  65.78829611382939,
#  65.4256327396193]

# %%
Quasilikelihood
# Out:
# [0.0923292128503,
#  0.09504761898294492,
#  0.09480581561359193,
#  0.09427525257964697,
#  0.09068673584436335,
#  0.09059218331232319,
#  0.0953529824520695,
#  0.09097769520858114,
#  0.09335077526859978,
#  0.0923130436349393,
#  0.09113262056878858,
#  0.09121032804795068,
#  0.08933491860043946,
#  0.09396912477710659,
#  0.09417555392075214]

# %%
plt.plot(forecasts["ds"], Y_true)
plt.plot(forecasts["ds"], Y_hat) 
plt.ylabel("S&P 500 Realized Volatility")
# Out:
# Text(0, 0.5, 'S&P 500 Realized Volatility')

# %% [markdown]
# # H=5 Forecasts

# %%
Accuracy=[]
RMSE=[]
Quasilikelihood=[]

# %%
test_length%5
# Out:
# 2

# %%
for i in range(14):
  model = NBEATSx(h=5, input_size=21,
                  loss=MQLoss(level=[90]),
                  scaler_type='minmax',
                  learning_rate= 0.0001,
                  stack_types=['identity','identity'],
                  n_blocks=[1,1],
                  mlp_units= [[512, 512], [512, 512]],
                  windows_batch_size=60,
                  num_lr_decays=5,
                  val_check_steps=100,
                  n_harmonics=0, n_polynomials=0,
                  hist_exog_list=['VIX','Temp. in Sao Paulo'],
                  max_steps=150,
                  early_stop_patience_steps=1,
                  random_seed=randrange(129228148)
                  )
  fcst = NeuralForecast(models=[model],freq=CustomBusinessDay(calendar=USFederalHolidayCalendar()))
  forecasts = fcst.cross_validation(df=df,val_size=10,static_df=AirPassengersStatic,n_windows=None, test_size=test_length-2,step_size=5)
  forecasts = forecasts.dropna()
  if "NBEATSx-median" not in list(forecasts.columns.values):
    Y_hat=forecasts["NBEATSx"].values
  else:
    Y_hat=forecasts["NBEATSx-median"].values
  Y_true=forecasts["y"].values
  RMSE.append(np.sum(np.sqrt((Y_true-Y_hat)**2))/len(Y_true))
  Accuracy.append((1-np.sum(np.sqrt((Y_true-Y_hat)**2)/Y_true)/(len(Y_true)))*100)
  Quasilikelihood.append(np.sum(Y_true/Y_hat-np.log(Y_true/Y_hat)-1)/len(Y_true))
# Out:
# INFO:lightning_fabric.utilities.seed:Global seed set to 11119403
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# INFO:lightning_fabric.utilities.seed:Global seed set to 113134330
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# INFO:lightning_fabric.utilities.seed:Global seed set to 42210334
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# INFO:lightning_fabric.utilities.seed:Global seed set to 27351393
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# INFO:lightning_fabric.utilities.seed:Global seed set to 85075820
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# INFO:lightning_fabric.utilities.seed:Global seed set to 35068740
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# INFO:lightning_fabric.utilities.seed:Global seed set to 90937328
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# INFO:lightning_fabric.utilities.seed:Global seed set to 67151856
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# INFO:lightning_fabric.utilities.seed:Global seed set to 121496633
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# INFO:lightning_fabric.utilities.seed:Global seed set to 71867664
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# INFO:lightning_fabric.utilities.seed:Global seed set to 3407793
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# INFO:lightning_fabric.utilities.seed:Global seed set to 11307507
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# INFO:lightning_fabric.utilities.seed:Global seed set to 16576806
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# INFO:lightning_fabric.utilities.seed:Global seed set to 88826767
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]

# %%
RMSE
# Out:
# [0.0024333147261817413,
#  0.0023780473085511303,
#  0.002415323581533488,
#  0.0024189563023674244,
#  0.002416104243844665,
#  0.0024313158708840236,
#  0.0023914220754157325,
#  0.0024118680301683337,
#  0.0024282557523831795,
#  0.00242986569011834,
#  0.002402274159299861,
#  0.002416451840771252,
#  0.0023951798545173942,
#  0.002404730429362998,
#  0.0024133863082559646]

# %%
Accuracy
# Out:
# [63.110071227969186,
#  63.919539543162784,
#  63.62847864915048,
#  63.335196517655355,
#  62.93127657392397,
#  62.53912004416753,
#  64.21787406397254,
#  63.391987911740244,
#  63.03363008100469,
#  62.50329846897347,
#  63.338257526690114,
#  62.734717863299196,
#  63.55418025985367,
#  64.13624767971217,
#  63.44408700407873]

# %%
Quasilikelihood
# Out:
# [0.11843537957559108,
#  0.11408598362277472,
#  0.11732208042976926,
#  0.1157304825105336,
#  0.11485742255372913,
#  0.11566715848784173,
#  0.11843071520355004,
#  0.11584556014939416,
#  0.11931282175157899,
#  0.11361368820900984,
#  0.1138896929624376,
#  0.1122545913621926,
#  0.11414569489997936,
#  0.11797719577661947,
#  0.11565536980320415]

# %%
plt.plot(forecasts["ds"], Y_true)
plt.plot(forecasts["ds"], Y_hat) 
plt.ylabel("S&P 500 Realized Volatility")
# Out:
# Text(0, 0.5, 'S&P 500 Realized Volatility')

# %% [markdown]
# # H=10 Forecasts

# %%
test_length%10
# Out:
# 7

# %%
Accuracy=[]
RMSE=[]
Quasilikelihood=[]

# %%
for i in range(13):
  model = NBEATSx(h=10, input_size=21,
                  loss=MQLoss(level=[90]),
                  scaler_type='minmax',
                  learning_rate= 0.0001,
                  stack_types=['identity','identity'],
                  n_blocks=[1,1],
                  mlp_units= [[512, 512], [512, 512]],
                  windows_batch_size=60,
                  num_lr_decays=5,
                  val_check_steps=100,
                  n_harmonics=0, n_polynomials=0,
                  hist_exog_list=['VIX','Temp. in Sao Paulo'],
                  max_steps=150,
                  early_stop_patience_steps=1,
                  random_seed=randrange(129228148)
                  )
  fcst = NeuralForecast(models=[model],freq=CustomBusinessDay(calendar=USFederalHolidayCalendar()))
  forecasts = fcst.cross_validation(df=df,val_size=10,static_df=AirPassengersStatic,n_windows=None, test_size=test_length-7,step_size=10)
  forecasts = forecasts.dropna()
  if "NBEATSx-median" not in list(forecasts.columns.values):
    Y_hat=forecasts["NBEATSx"].values
  else:
    Y_hat=forecasts["NBEATSx-median"].values
  Y_true=forecasts["y"].values
  RMSE.append(np.sum(np.sqrt((Y_true-Y_hat)**2))/len(Y_true))
  Accuracy.append((1-np.sum(np.sqrt((Y_true-Y_hat)**2)/Y_true)/(len(Y_true)))*100)
  Quasilikelihood.append(np.sum(Y_true/Y_hat-np.log(Y_true/Y_hat)-1)/len(Y_true))
# Out:
# INFO:lightning_fabric.utilities.seed:Global seed set to 76268473
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# INFO:lightning_fabric.utilities.seed:Global seed set to 94544014
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# INFO:lightning_fabric.utilities.seed:Global seed set to 42305376
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# INFO:lightning_fabric.utilities.seed:Global seed set to 20506051
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# INFO:lightning_fabric.utilities.seed:Global seed set to 110358595
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# INFO:lightning_fabric.utilities.seed:Global seed set to 40494101
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# INFO:lightning_fabric.utilities.seed:Global seed set to 28571659
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# INFO:lightning_fabric.utilities.seed:Global seed set to 40547473
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# INFO:lightning_fabric.utilities.seed:Global seed set to 117549067
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# INFO:lightning_fabric.utilities.seed:Global seed set to 99161161
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# INFO:lightning_fabric.utilities.seed:Global seed set to 37391579
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# INFO:lightning_fabric.utilities.seed:Global seed set to 101970981
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# INFO:lightning_fabric.utilities.seed:Global seed set to 44799487
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]

# %%
RMSE
# Out:
# [0.002911216327498411,
#  0.002924574119593978,
#  0.0029333686531368593,
#  0.0029521490018577464,
#  0.0029679633477706054,
#  0.0029440341468640495,
#  0.0029473829349577767,
#  0.0029492518506397487,
#  0.0029705349162958946,
#  0.002937446851033522,
#  0.002965665937028923,
#  0.0029617025695747416,
#  0.0029919811813276156,
#  0.0029437619015150697,
#  0.0029882892231308795]

# %%
Accuracy
# Out:
# [54.56713284888157,
#  54.123838758111106,
#  53.75510055897315,
#  53.54471807531136,
#  53.01234704628567,
#  53.90674958307091,
#  53.42496666939041,
#  53.885329773620796,
#  53.03750629752464,
#  53.96638887008767,
#  53.71553483970873,
#  53.50666472284065,
#  52.81896372325989,
#  53.1721108016366,
#  53.13719050790351]

# %%
Quasilikelihood
# Out:
# [0.1699131407549612,
#  0.16044351281814856,
#  0.1688026315327873,
#  0.16910028173811228,
#  0.16831650263902384,
#  0.17350298969059175,
#  0.16799584758156788,
#  0.17767848730067237,
#  0.16981846110657972,
#  0.17220074396528462,
#  0.17337229604765214,
#  0.16960836307573415,
#  0.16874680528411157,
#  0.16372296034028574,
#  0.17263916154426245]

# %%
plt.plot(forecasts["ds"], Y_true)
plt.plot(forecasts["ds"], Y_hat) 
plt.ylabel("S&P 500 Realized Volatility")
# Out:
# Text(0, 0.5, 'S&P 500 Realized Volatility')

# %% [markdown]
# # H=22 Forecasts

# %%
test_length%22
# Out:
# 19

# %%
Accuracy=[]
RMSE=[]
Quasilikelihood=[]

# %%
for i in range(14):
  model = NBEATSx(h=22, input_size=21,
                  loss=MQLoss(level=[90]),
                  scaler_type='minmax',
                  learning_rate= 0.0001,
                  stack_types=['identity','identity'],
                  n_blocks=[1,1],
                  mlp_units= [[512, 512], [512, 512]],
                  windows_batch_size=60,
                  num_lr_decays=5,
                  val_check_steps=100,
                  n_harmonics=0, n_polynomials=0,
                  hist_exog_list=['VIX','Temp. in Sao Paulo'],
                  max_steps=150,
                  early_stop_patience_steps=1,
                  random_seed=randrange(129228148)
                  )
  fcst = NeuralForecast(models=[model],freq=CustomBusinessDay(calendar=USFederalHolidayCalendar()))
  forecasts = fcst.cross_validation(df=df,val_size=22,static_df=AirPassengersStatic,n_windows=None, test_size=test_length-19,step_size=22)
  forecasts = forecasts.dropna()
  if "NBEATSx-median" not in list(forecasts.columns.values):
    Y_hat=forecasts["NBEATSx"].values
  else:
    Y_hat=forecasts["NBEATSx-median"].values
  Y_true=forecasts["y"].values
  RMSE.append(np.sum(np.sqrt((Y_true-Y_hat)**2))/len(Y_true))
  Accuracy.append((1-np.sum(np.sqrt((Y_true-Y_hat)**2)/Y_true)/(len(Y_true)))*100)
  Quasilikelihood.append(np.sum(Y_true/Y_hat-np.log(Y_true/Y_hat)-1)/len(Y_true))
# Out:
# INFO:lightning_fabric.utilities.seed:Global seed set to 82027806
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# INFO:lightning_fabric.utilities.seed:Global seed set to 110023569
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# INFO:lightning_fabric.utilities.seed:Global seed set to 34321210
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# INFO:lightning_fabric.utilities.seed:Global seed set to 93677924
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# INFO:lightning_fabric.utilities.seed:Global seed set to 57322247
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# INFO:lightning_fabric.utilities.seed:Global seed set to 36411709
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# INFO:lightning_fabric.utilities.seed:Global seed set to 95139058
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# INFO:lightning_fabric.utilities.seed:Global seed set to 5349511
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# INFO:lightning_fabric.utilities.seed:Global seed set to 5802077
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# INFO:lightning_fabric.utilities.seed:Global seed set to 47013460
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# INFO:lightning_fabric.utilities.seed:Global seed set to 83909099
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# INFO:lightning_fabric.utilities.seed:Global seed set to 44882214
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# INFO:lightning_fabric.utilities.seed:Global seed set to 58144397
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]
# INFO:lightning_fabric.utilities.seed:Global seed set to 100756713
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Predicting: 0it [00:00, ?it/s]

# %%
RMSE
# Out:
# [0.003706938052946938,
#  0.0036354479100818445,
#  0.003694409904064163,
#  0.0036623692048180067,
#  0.0036478267715993346,
#  0.0036751223237222554,
#  0.0036804981764231894,
#  0.0036906904932034637,
#  0.003698450363472625,
#  0.003696091288606784,
#  0.003654949507023944,
#  0.003644978002262868,
#  0.003637369638740514,
#  0.003625556391376408,
#  0.0036664768178417315]

# %%
Accuracy
# Out:
# [38.28095461367656,
#  39.21553393331387,
#  38.45403994479511,
#  38.861468138586815,
#  39.08775903425994,
#  38.705085017165,
#  38.32428217087962,
#  38.55273626981726,
#  38.36215715233359,
#  38.53683778416238,
#  38.8782278520326,
#  39.40048072413922,
#  39.10698451107927,
#  39.65939471539358,
#  38.82250042715803]

# %%
Quasilikelihood
# Out:
# [0.2475658442345698,
#  0.2383207224278829,
#  0.24775146544714013,
#  0.23596861285667378,
#  0.2370138449356049,
#  0.24432409349780831,
#  0.2342148335779239,
#  0.2420311239464234,
#  0.24182088750699732,
#  0.24566764722172268,
#  0.237659380190034,
#  0.23875193188663096,
#  0.2338551507965194,
#  0.23754674901034864,
#  0.23774678256586243]

# %%
plt.plot(forecasts["ds"], Y_true)
plt.plot(forecasts["ds"], Y_hat) 
plt.ylabel("S&P 500 Realized Volatility")
# Out:
# Text(0, 0.5, 'S&P 500 Realized Volatility')
