# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # S&P 500

# %%
H_1=pd.read_excel("H=1.xlsx",index_col='Date',parse_dates=True,sheet_name="S&P500")
H_3=pd.read_excel("H=3.xlsx",index_col='Date',parse_dates=True,sheet_name="S&P500")
H_5=pd.read_excel("H=5.xlsx",index_col='Date',parse_dates=True,sheet_name="S&P500")
H_10=pd.read_excel("H=10.xlsx",index_col='Date',parse_dates=True,sheet_name="S&P500")
H_22=pd.read_excel("H=22.xlsx",index_col='Date',parse_dates=True,sheet_name="S&P500")

# %%
H_1.reset_index(inplace=True)
H_3.reset_index(inplace=True)
H_5.reset_index(inplace=True)
H_10.reset_index(inplace=True)
H_22.reset_index(inplace=True)

# %%
plt.plot(H_1["Date"], H_1["Actuals"])
plt.plot(H_1["Date"], H_1["DJR-GARCH"])  
plt.ylabel("S&P 500 Realized Volatility")
# Out:
# Text(0, 0.5, 'S&P 500 Realized Volatility')

# %%
plt.plot(H_3["Date"], H_3["Actuals"])
plt.plot(H_3["Date"], H_3["DJR-GARCH"])  
plt.ylabel("S&P 500 Realized Volatility")
# Out:
# Text(0, 0.5, 'S&P 500 Realized Volatility')

# %%
plt.plot(H_5["Date"], H_5["Actuals"])
plt.plot(H_5["Date"], H_5["DJR-GARCH"])  
plt.ylabel("S&P 500 Realized Volatility")
# Out:
# Text(0, 0.5, 'S&P 500 Realized Volatility')

# %%
plt.plot(H_10["Date"], H_10["Actuals"])
plt.plot(H_10["Date"], H_10["DJR-GARCH"])  
plt.ylabel("S&P 500 Realized Volatility")
# Out:
# Text(0, 0.5, 'S&P 500 Realized Volatility')

# %%
plt.plot(H_22["Date"], H_22["Actuals"])
plt.plot(H_22["Date"], H_22["DJR-GARCH"])  
plt.ylabel("S&P 500 Realized Volatility")
# Out:
# Text(0, 0.5, 'S&P 500 Realized Volatility')

# %% [markdown]
# # NASDAQ

# %%
H_1=pd.read_excel("H=1.xlsx",index_col='Date',parse_dates=True,sheet_name="NASDAQ")
H_3=pd.read_excel("H=3.xlsx",index_col='Date',parse_dates=True,sheet_name="NASDAQ")
H_5=pd.read_excel("H=5.xlsx",index_col='Date',parse_dates=True,sheet_name="NASDAQ")
H_10=pd.read_excel("H=10.xlsx",index_col='Date',parse_dates=True,sheet_name="NASDAQ")
H_22=pd.read_excel("H=22.xlsx",index_col='Date',parse_dates=True,sheet_name="NASDAQ")

# %%
H_1.reset_index(inplace=True)
H_3.reset_index(inplace=True)
H_5.reset_index(inplace=True)
H_10.reset_index(inplace=True)
H_22.reset_index(inplace=True)

# %%
plt.plot(H_1["Date"], H_1["Actuals"])
plt.plot(H_1["Date"], H_1["DJR-GARCH"])  
plt.ylabel("NASDAQ Realized Volatility")
# Out:
# Text(0, 0.5, 'NASDAQ Realized Volatility')

# %%
plt.plot(H_3["Date"], H_3["Actuals"])
plt.plot(H_3["Date"], H_3["DJR-GARCH"])  
plt.ylabel("NASDAQ Realized Volatility")
# Out:
# Text(0, 0.5, 'NASDAQ Realized Volatility')

# %%
plt.plot(H_5["Date"], H_5["Actuals"])
plt.plot(H_5["Date"], H_5["DJR-GARCH"])  
plt.ylabel("NASDAQ Realized Volatility")
# Out:
# Text(0, 0.5, 'NASDAQ Realized Volatility')

# %%
plt.plot(H_10["Date"], H_10["Actuals"])
plt.plot(H_10["Date"], H_10["DJR-GARCH"])  
plt.ylabel("NASDAQ Realized Volatility")
# Out:
# Text(0, 0.5, 'NASDAQ Realized Volatility')

# %%
plt.plot(H_22["Date"], H_22["Actuals"])
plt.plot(H_22["Date"], H_22["DJR-GARCH"])  
plt.ylabel("NASDAQ Realized Volatility")
# Out:
# Text(0, 0.5, 'NASDAQ Realized Volatility')

# %% [markdown]
# # DJIA

# %%
H_1=pd.read_excel("H=1.xlsx",index_col='Date',parse_dates=True,sheet_name="DJIA")
H_3=pd.read_excel("H=3.xlsx",index_col='Date',parse_dates=True,sheet_name="DJIA")
H_5=pd.read_excel("H=5.xlsx",index_col='Date',parse_dates=True,sheet_name="DJIA")
H_10=pd.read_excel("H=10.xlsx",index_col='Date',parse_dates=True,sheet_name="DJIA")
H_22=pd.read_excel("H=22.xlsx",index_col='Date',parse_dates=True,sheet_name="DJIA")

# %%
H_1.reset_index(inplace=True)
H_3.reset_index(inplace=True)
H_5.reset_index(inplace=True)
H_10.reset_index(inplace=True)
H_22.reset_index(inplace=True)

# %%
plt.plot(H_1["Date"], H_1["Actuals"])
plt.plot(H_1["Date"], H_1["DJR-GARCH"])  
plt.ylabel("DJIA Realized Volatility")
# Out:
# Text(0, 0.5, 'DJIA Realized Volatility')

# %%
plt.plot(H_3["Date"], H_3["Actuals"])
plt.plot(H_3["Date"], H_3["DJR-GARCH"])  
plt.ylabel("DJIA Realized Volatility")
# Out:
# Text(0, 0.5, 'DJIA Realized Volatility')

# %%
plt.plot(H_5["Date"], H_5["Actuals"])
plt.plot(H_5["Date"], H_5["DJR-GARCH"])  
plt.ylabel("DJIA Realized Volatility")
# Out:
# Text(0, 0.5, 'DJIA Realized Volatility')

# %%
plt.plot(H_10["Date"], H_10["Actuals"])
plt.plot(H_10["Date"], H_10["DJR-GARCH"])  
plt.ylabel("DJIA Realized Volatility")
# Out:
# Text(0, 0.5, 'DJIA Realized Volatility')

# %%
plt.plot(H_22["Date"], H_22["Actuals"])
plt.plot(H_22["Date"], H_22["DJR-GARCH"])  
plt.ylabel("DJIA Realized Volatility")
# Out:
# Text(0, 0.5, 'DJIA Realized Volatility')
